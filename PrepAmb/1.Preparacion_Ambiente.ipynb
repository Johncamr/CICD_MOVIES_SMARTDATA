# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
create widget text nameStorage default "adlsmovieproject";

# %%
# %sql
DROP CATALOG IF EXISTS catalog_movie_project CASCADE;
CREATE CATALOG IF NOT EXISTS catalog_movie_project;

# %%
# %sql
-- CREATE SCHEMA IF NOT EXISTS catalog_movie_project.raw;
CREATE SCHEMA IF NOT EXISTS catalog_movie_project.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_movie_project.silver;
CREATE SCHEMA IF NOT EXISTS catalog_movie_project.golden;

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${nameStorage}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas raw del Data Lake';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-unit-catalog`
URL 'abfss://unit-catalog@${nameStorage}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas unit-catalog del Data Lake';

# %%
# %sql
DROP VOLUME IF EXISTS catalog_movie_project.bronze.data;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS catalog_movie_project.bronze.data;
